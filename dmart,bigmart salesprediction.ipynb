# %%
import pandas as pd

# %%
dff=pd.read_csv('test.csv')

# %%
dff

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dff.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df['Item_Weight'].fillna(round(df['Item_Weight'].mean()),inplace=True)
d=df.drop(['Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size'],axis=1)

# %%
d
# Out:
#      Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0              FDA15        9.300         0.016047  249.8092
# 1              DRC01        5.920         0.019278   48.2692
# 2              FDN15       17.500         0.016760  141.6180
# 3              FDX07       19.200         0.000000  182.0950
# 4              NCD19        8.930         0.000000   53.8614
# ...              ...          ...              ...       ...
# 8518           FDF22        6.865         0.056783  214.5218
# 8519           FDS36        8.380         0.046982  108.1570
# 8520           NCJ29       10.600         0.035186   85.1224
# 8521           FDN46        7.210         0.145221  103.1332
# 8522           DRG01       14.800         0.044878   75.4670
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0                  Tier 1  Supermarket Type1          3735.1380
# 1                  Tier 3  Supermarket Type2           443.4228
# ...

# %%
d['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
d.isnull().sum()
# Out:
# Item_Identifier         0
# Item_Weight             0
# Item_Visibility         0
# Item_MRP                0
# Outlet_Location_Type    0
# Outlet_Type             0
# Item_Outlet_Sales       0
# dtype: int64

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
d['Outlet_Type']=le.fit_transform(d['Outlet_Type'])
d['Outlet_Location_Type']=le.fit_transform(d['Outlet_Location_Type'])
d['Item_Identifier']=le.fit_transform(d['Item_Identifier'])

# %%
d
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0                 156        9.300         0.016047  249.8092
# 1                   8        5.920         0.019278   48.2692
# 2                 662       17.500         0.016760  141.6180
# 3                1121       19.200         0.000000  182.0950
# 4                1297        8.930         0.000000   53.8614
# ...               ...          ...              ...       ...
# 8518              370        6.865         0.056783  214.5218
# 8519              897        8.380         0.046982  108.1570
# 8520             1357       10.600         0.035186   85.1224
# 8521              681        7.210         0.145221  103.1332
# 8522               50       14.800         0.044878   75.4670
#
#       Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                        0            1          3735.1380
# 1                        2            2           443.4228
# ...

# %%
d['Outlet_Location_Type'].value_counts()
# Out:
# 2    3350
# 1    2785
# 0    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
d['Outlet_Type'].value_counts()
# Out:
# 1    5577
# 0    1083
# 3     935
# 2     928
# Name: Outlet_Type, dtype: int64

# %%
d
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0                 156        9.300         0.016047  249.8092
# 1                   8        5.920         0.019278   48.2692
# 2                 662       17.500         0.016760  141.6180
# 3                1121       19.200         0.000000  182.0950
# 4                1297        8.930         0.000000   53.8614
# ...               ...          ...              ...       ...
# 8518              370        6.865         0.056783  214.5218
# 8519              897        8.380         0.046982  108.1570
# 8520             1357       10.600         0.035186   85.1224
# 8521              681        7.210         0.145221  103.1332
# 8522               50       14.800         0.044878   75.4670
#
#       Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                        0            1          3735.1380
# 1                        2            2           443.4228
# ...

# %%
d.isnull().sum()
# Out:
# Item_Identifier         0
# Item_Weight             0
# Item_Visibility         0
# Item_MRP                0
# Outlet_Location_Type    0
# Outlet_Type             0
# Item_Outlet_Sales       0
# dtype: int64

# %%
d
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0                 156        9.300         0.016047  249.8092
# 1                   8        5.920         0.019278   48.2692
# 2                 662       17.500         0.016760  141.6180
# 3                1121       19.200         0.000000  182.0950
# 4                1297        8.930         0.000000   53.8614
# ...               ...          ...              ...       ...
# 8518              370        6.865         0.056783  214.5218
# 8519              897        8.380         0.046982  108.1570
# 8520             1357       10.600         0.035186   85.1224
# 8521              681        7.210         0.145221  103.1332
# 8522               50       14.800         0.044878   75.4670
#
#       Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                        0            1          3735.1380
# 1                        2            2           443.4228
# ...

# %%
X=d.drop(columns='Item_Outlet_Sales',axis=1)

# %%
print(X)
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0                 156        9.300         0.016047  249.8092
# 1                   8        5.920         0.019278   48.2692
# 2                 662       17.500         0.016760  141.6180
# 3                1121       19.200         0.000000  182.0950
# 4                1297        8.930         0.000000   53.8614
# ...               ...          ...              ...       ...
# 8518              370        6.865         0.056783  214.5218
# 8519              897        8.380         0.046982  108.1570
# 8520             1357       10.600         0.035186   85.1224
# 8521              681        7.210         0.145221  103.1332
# 8522               50       14.800         0.044878   75.4670
#
#       Outlet_Location_Type  Outlet_Type
# 0                        0            1
# 1                        2            2
# 2                        0            1
# 3                        2            0
# ...

# %%
Y=d['Item_Outlet_Sales']

# %%
print(Y)
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=5)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics

# %%
z1=lr.predict(X_train)

# %%
r_train=metrics.r2_score(Y_train,z1)

# %%
r_train
# Out:
# 0.5020872989400716

# %%
z=lr.predict(X_test)

# %%
r_test=metrics.r2_score(Y_test,z)

# %%
r_test
# Out:
# 0.49321735784979515

# %%
pd.DataFrame(d,columns=['Item_Outlet_Sales']).to_csv('Linearreg.csv')

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
z3=rfr.predict(X_train)

# %%
r_train=metrics.r2_score(Y_train,z3)

# %%
r_train     # overfitting model
# Out:
# 0.9364518810284848

# %%
z4=rfr.predict(X_test)

# %%
r_test=metrics.r2_score(Y_test,z4)

# %%
r_test
# Out:
# 0.5202573988469187

# %%
import pickle # this model is for saving the algorithm model and arranging and storing in fileformatt

# %%
filename='savvmodel.sav'

# %%
pickle.dump(lr,open(filename,'wb'))

# %%
X_test.head()
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 2095              270       10.895         0.009614  122.9730
# 3271              988       16.700         0.071335  120.3782
# 5055             1356       18.600         0.118180   56.2588
# 8307             1514       20.200         0.066066   61.3510
# 1923              548        5.785         0.040325  180.4660
#
#       Outlet_Location_Type  Outlet_Type
# 2095                     2            1
# 3271                     2            0
# 5055                     0            1
# 8307                     1            1
# 1923                     2            1

# %%
load_model=pickle.load(open(filename,'rb'))

# %%
load_model.predict([[1500,100,0.2,1000,2,2]])
# Out:
# array([15586.98438007])

# %%
filename='davvmiodel.sav'

# %%
pickle.dump(rfr,open(filename,'wb'))

# %%
load_model=pickle.load(open(filename,'rb'))

# %%
load_model.predict([[1900,100,0.22,500,2,1]])
# Out:
# array([5078.629188])

# %%
import pandas as pd
import numpy as np

# %%
X=pd.read_csv('Train.csv')
Y=pd.read_csv('test.csv')

# %%
X
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
Y
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
X.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
Y.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
import pandas as pd    # BIGMART SALES PREDICTION
import numpy as np

# %%
X
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
d
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0                 156        9.300         0.016047  249.8092
# 1                   8        5.920         0.019278   48.2692
# 2                 662       17.500         0.016760  141.6180
# 3                1121       19.200         0.000000  182.0950
# 4                1297        8.930         0.000000   53.8614
# ...               ...          ...              ...       ...
# 8518              370        6.865         0.056783  214.5218
# 8519              897        8.380         0.046982  108.1570
# 8520             1357       10.600         0.035186   85.1224
# 8521              681        7.210         0.145221  103.1332
# 8522               50       14.800         0.044878   75.4670
#
#       Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                        0            1          3735.1380
# 1                        2            2           443.4228
# ...

# %%
data={'Item_Identifier':1500,'Item_Weight':100,'Item_Visibility':0.2,'Item_MRP':1000,'Outlet_Location_Type':2,'Outlet_Type':2}
index=[8523]
new_ps=pd.DataFrame(data,index)
(new_ps)
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 8523             1500          100              0.2      1000
#
#       Outlet_Location_Type  Outlet_Type
# 8523                     2            2

# %%
value_prdct=lr.predict(new_ps)
value_prdct
# Out:
# array([15586.98438007])

# %%
value_prdct=rfr.predict(new_ps)
print(value_prdct)
# Out:
# [4901.865946]
