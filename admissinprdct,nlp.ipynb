# %%
df=pd.read_csv('Admission_Prediction.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3        NaN        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1      337.0        118.0                4.0  4.5  4.5  9.65
# 1           2      324.0        107.0                4.0  4.0  4.5  8.87
# 2           3        NaN        104.0                3.0  3.0  3.5  8.00
# 3           4      322.0        110.0                3.0  3.5  2.5  8.67
# 4           5      314.0        103.0                2.0  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
df.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 495         1             0.87
# 496         1             0.96
# 497         1             0.93
# 498         0             0.73
# 499         0             0.84

# %%
df.isnull().sum()
# Out:
# Serial No.            0
# GRE Score            15
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
df['GRE Score'].fillna(round(df['GRE Score'].mean()),inplace=True)
df['TOEFL Score'].fillna(round(df['TOEFL Score'].mean()),inplace=True)
df['University Rating'].fillna(df['University Rating'].mode()[0],inplace=True)

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      317.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    float64
#  2   TOEFL Score        500 non-null    float64
#  3   University Rating  500 non-null    float64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 35.3 KB

# %%
df['Chance of Admit']=df['Chance of Admit'].apply(lambda x:1 if x>0.75 else 0)

# %%
df['Chance of Admit'].value_counts()
# Out:
# 0    290
# 1    210
# Name: Chance of Admit, dtype: int64

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      317.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1                1
# ...

# %%
X=df.drop('Chance of Admit',axis=1)

# %%
X
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      317.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research
# 0           1
# 1           1
# 2           1
# ...

# %%
Y=df['Chance of Admit']

# %%
Y
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 495    1
# 496    1
# 497    1
# 498    0
# 499    1
# Name: Chance of Admit, Length: 500, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=5)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
log.fit(X_train,Y_train)
# Out:
# C:\Users\pavani\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
z=log.predict(X_test)

# %%
accuracy_score(Y_test,z)*100
# Out:
# 79.0

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtcc=DecisionTreeClassifier()

# %%
dtcc.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
z1=dtcc.predict(X_test)

# %%
accuracy_score(Y_test,z1)*100
# Out:
# 81.0

# %%
df['Chance of Admit'].replace(0,'no admission',inplace=True)
df['Chance of Admit'].replace(1,'get admission',inplace=True)

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      317.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research Chance of Admit
# 0           1   get admission
# ...

# %%
pd.DataFrame(df,columns=['Chance of Admit']).to_csv('dtadmissprdct.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      317.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research Chance of Admit
# 0           1   get admission
# ...

# %%
data={'Serial No':501,'GRE Score':340,'TOEFL Score':120,'University Rating':4,'SOP':6,'LOR':7,'CGPA':9,'Research':1}
index=[501]
new_ps=pd.DataFrame(data,index)
new_ps
# Out:
#      Serial No  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 501        501        340          120                  4    6    7     9
#
#      Research
# 501         1

# %%
import pickle

# %%
filename='savvsos.sav'

# %%
pickle.dump(log,open(filename,'wb'))

# %%
load=pickle.load(open(filename,'rb'))

# %%
load.predict([[501,340,120,4,6,7,9,1]])
# Out:
# array([1], dtype=int64)

# %%
valu_prdct=dtcc.predict(new_ps)

# %%
valu_prdct
# Out:
# array([1], dtype=int64)

# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv('unclean focus (1).csv')

# %%
a
# Out:
#        model    year     price transmission mileage fuel type engine size  \
# 0      Focus  2016.0    £8,000       Manual     NaN    Petrol       0.999
# 1      Focus  2019.0   £13,400       Manual     NaN    Petrol       0.999
# 2      Focus  2019.0   £14,600       Manual     NaN    Petrol       1.498
# 3      Focus  2016.0    £9,450       Manual     NaN    Diesel        1.56
# 4      Focus  2015.0    £9,999       Manual     NaN    Diesel        1.56
# ...      ...     ...       ...          ...     ...       ...         ...
# 5599   Focus  2019.0   £18,745       Manual     NaN    Diesel           2
# 5600   Focus  2019.0   £16,350       Manual     NaN    Petrol           1
# 5601   Focus  2019.0   £16,850       Manual     NaN    Petrol           1
# 5602   Focus  2019.0   £17,310    Automatic     NaN    Petrol           1
# 5603   Focus  2019.0   £17,610    Automatic     NaN    Petrol           1
#
#      mileage2 fuel type2 engine size2     reference
# ...

# %%
a.head()
# Out:
#     model    year     price transmission mileage fuel type engine size  \
# 0   Focus  2016.0    £8,000       Manual     NaN    Petrol       0.999
# 1   Focus  2019.0   £13,400       Manual     NaN    Petrol       0.999
# 2   Focus  2019.0   £14,600       Manual     NaN    Petrol       1.498
# 3   Focus  2016.0    £9,450       Manual     NaN    Diesel        1.56
# 4   Focus  2015.0    £9,999       Manual     NaN    Diesel        1.56
#
#   mileage2 fuel type2 engine size2     reference
# 0   38,852        NaN          NaN  /ad/25451236
# 1   11,952        NaN          NaN  /ad/25466927
# 2   22,142        NaN          NaN  /ad/25484363
# 3   14,549        NaN          NaN  /ad/20444868
# 4    7,010        NaN          NaN  /ad/22551057

# %%
a.isnull().sum()
# Out:
# model             56
# year             145
# price             56
# transmission      56
# mileage          875
# fuel type       3416
# engine size      101
# mileage2          95
# fuel type2       875
# engine size2     875
# reference         56
# dtype: int64

# %%
d=a.drop(['reference','fuel type2','engine size2','year','mileage'],axis=1)

# %%
d
# Out:
#        model     price transmission fuel type engine size mileage2
# 0      Focus    £8,000       Manual    Petrol       0.999   38,852
# 1      Focus   £13,400       Manual    Petrol       0.999   11,952
# 2      Focus   £14,600       Manual    Petrol       1.498   22,142
# 3      Focus    £9,450       Manual    Diesel        1.56   14,549
# 4      Focus    £9,999       Manual    Diesel        1.56    7,010
# ...      ...       ...          ...       ...         ...      ...
# 5599   Focus   £18,745       Manual    Diesel           2    7,855
# 5600   Focus   £16,350       Manual    Petrol           1   13,891
# 5601   Focus   £16,850       Manual    Petrol           1   13,452
# 5602   Focus   £17,310    Automatic    Petrol           1   13,376
# 5603   Focus   £17,610    Automatic    Petrol           1    7,886
#
# [5604 rows x 6 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5604 entries, 0 to 5603
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         5548 non-null   object
#  1   year          5459 non-null   float64
#  2   price         5548 non-null   object
#  3   transmission  5548 non-null   object
#  4   mileage       4729 non-null   object
#  5   fuel type     2188 non-null   object
#  6   engine size   5503 non-null   object
#  7   mileage2      5509 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 350.4+ KB

# %%
d.isnull().sum()
# Out:
# model             56
# year             145
# price             56
# transmission      56
# mileage          875
# fuel type       3416
# engine size      101
# mileage2          95
# dtype: int64

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      317.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1                1
# ...

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
X
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      317.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research
# 0           1
# 1           1
# 2           1
# ...

# %%
Y
# Out:
# 0      get admission
# 1      get admission
# 2       no admission
# 3      get admission
# 4       no admission
#            ...
# 495    get admission
# 496    get admission
# 497    get admission
# 498     no admission
# 499    get admission
# Name: Chance of Admit, Length: 500, dtype: object

# %%
d
# Out:
#        model     price transmission fuel type engine size mileage2
# 0      Focus    £8,000       Manual    Petrol       0.999   38,852
# 1      Focus   £13,400       Manual    Petrol       0.999   11,952
# 2      Focus   £14,600       Manual    Petrol       1.498   22,142
# 3      Focus    £9,450       Manual    Diesel        1.56   14,549
# 4      Focus    £9,999       Manual    Diesel        1.56    7,010
# ...      ...       ...          ...       ...         ...      ...
# 5599   Focus   £18,745       Manual    Diesel           2    7,855
# 5600   Focus   £16,350       Manual    Petrol           1   13,891
# 5601   Focus   £16,850       Manual    Petrol           1   13,452
# 5602   Focus   £17,310    Automatic    Petrol           1   13,376
# 5603   Focus   £17,610    Automatic    Petrol           1    7,886
#
# [5604 rows x 6 columns]

# %%
d['price'].fillna(d['price'].mean(),inplace=True)
d['engine size'].fillna(d['engine size'].mean(),inplace=True)
d['mileage2'].fillna(d['mileage2'].mean(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6404/2378566679.py in <module>
# ----> 1 d['price'].fillna(d['price'].mean(),inplace=True)
#       2 d['engine size'].fillna(d['engine size'].mean(),inplace=True)
#       3 d['mileage2'].fillna(d['mileage2'].mean(),inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Fish.csv')

# %%
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
X=df.iloc[:,1:7].values

# %%
X
# Out:
# array([[2.42000e+02, 2.32000e+01, 2.54000e+01, 3.00000e+01, 1.15200e+01,
#         4.02000e+00],
#        [2.90000e+02, 2.40000e+01, 2.63000e+01, 3.12000e+01, 1.24800e+01,
#         4.30560e+00],
#        [3.40000e+02, 2.39000e+01, 2.65000e+01, 3.11000e+01, 1.23778e+01,
#         4.69610e+00],
#        [3.63000e+02, 2.63000e+01, 2.90000e+01, 3.35000e+01, 1.27300e+01,
#         4.45550e+00],
#        [4.30000e+02, 2.65000e+01, 2.90000e+01, 3.40000e+01, 1.24440e+01,
#         5.13400e+00],
#        [4.50000e+02, 2.68000e+01, 2.97000e+01, 3.47000e+01, 1.36024e+01,
#         4.92740e+00],
#        [5.00000e+02, 2.68000e+01, 2.97000e+01, 3.45000e+01, 1.41795e+01,
#         5.27850e+00],
#        [3.90000e+02, 2.76000e+01, 3.00000e+01, 3.50000e+01, 1.26700e+01,
#         4.69000e+00],
#        [4.50000e+02, 2.76000e+01, 3.00000e+01, 3.51000e+01, 1.40049e+01,
#         4.84380e+00],
#        [5.00000e+02, 2.85000e+01, 3.07000e+01, 3.62000e+01, 1.42266e+01,
#         4.95940e+00],
# ...

# %%
y=df.iloc[:,0].values

# %%
y
# Out:
# array(['Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream',
#        'Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream',
#        'Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream',
#        'Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream',
#        'Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream', 'Bream',
#        'Roach', 'Roach', 'Roach', 'Roach', 'Roach', 'Roach', 'Roach',
#        'Roach', 'Roach', 'Roach', 'Roach', 'Roach', 'Roach', 'Roach',
#        'Roach', 'Roach', 'Roach', 'Roach', 'Roach', 'Roach', 'Whitefish',
#        'Whitefish', 'Whitefish', 'Whitefish', 'Whitefish', 'Whitefish',
#        'Parkki', 'Parkki', 'Parkki', 'Parkki', 'Parkki', 'Parkki',
#        'Parkki', 'Parkki', 'Parkki', 'Parkki', 'Parkki', 'Perch', 'Perch',
#        'Perch', 'Perch', 'Perch', 'Perch', 'Perch', 'Perch', 'Perch',
#        'Perch', 'Perch', 'Perch', 'Perch', 'Perch', 'Perch', 'Perch',
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=4)

# %%
X_train.shape
# Out:
# (143, 6)

# %%
X_test.shape
# Out:
# (16, 6)

# %%
y_train.shape
# Out:
# (143,)

# %%
y_test.shape
# Out:
# (16,)

# %%
lrr=LogisticRegression()
dtc=DecisionTreeClassifier()

# %%
lrr.fit(X_train,y_train)
# Out:
# C:\Users\pavani\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
z=lrr.predict(X_test)

# %%
accuracy_score(y_test,z)*100
# Out:
# 68.75

# %%
z1=dtc.predict(X_test)

# %%
accuracy_score(y_test,z1)*100
# Out:
# 81.25

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
z2=rfc.predict(X_test)

# %%
accuracy_score(y_test,z2)*100
# Out:
# 93.75

# %%
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
print(.predict([[5,6,7,8,9,10]]))
# Out:
# ['Smelt']

# %%
c=pd.read_csv('winequality-red.csv')

# %%
c
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
d=pd.read_csv('winequality-white.csv')

# %%
d
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
dff=pd.concat([c,d])

# %%
dff
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
dff.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
X=dff.iloc[:,0:11].values

# %%
X
# Out:
# array([[ 7.4 ,  0.7 ,  0.  , ...,  3.51,  0.56,  9.4 ],
#        [ 7.8 ,  0.88,  0.  , ...,  3.2 ,  0.68,  9.8 ],
#        [ 7.8 ,  0.76,  0.04, ...,  3.26,  0.65,  9.8 ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  2.99,  0.46,  9.4 ],
#        [ 5.5 ,  0.29,  0.3 , ...,  3.34,  0.38, 12.8 ],
#        [ 6.  ,  0.21,  0.38, ...,  3.26,  0.32, 11.8 ]])

# %%
y=dff.iloc[:,11].values

# %%
y
# Out:
# array([5, 5, 5, ..., 6, 7, 6], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import svm

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
lr1=LogisticRegression()
dtcc=DecisionTreeClassifier()
rfcc=RandomForestClassifier()
lrr2=LinearRegression()
svm=svm.SVC()

# %%
lr1.fit(X_train,y_train)
# Out:
# C:\Users\pavani\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
dtcc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
rfcc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
lrr2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
t=lr1.predict(X_test)

# %%
accuracy_score(y_test,t)*100
# Out:
# 47.30769230769231

# %%
t1=dtcc.predict(X_test)

# %%
accuracy_score(y_test,t1)*100
# Out:
# 61.53846153846154

# %%
t2=rfcc.predict(X_test)

# %%
accuracy_score(y_test,t2)*100
# Out:
# 70.15384615384616

# %%
t3=svm.predict(X_test)

# %%
accuracy_score(y_test,t3)*100
# Out:
# 42.38461538461539

# %%
dff
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
print(svm.predict([[5,1,1,5,0.4,8,10,1,]]))

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
acale=MinMaxScaler()

# %%
print(acale.fit_transform(df[['5.1','3.5']]))
# Out:
# [[0.16666667 0.41666667]
#  [0.11111111 0.5       ]
#  [0.08333333 0.45833333]
#  [0.19444444 0.66666667]
#  [0.30555556 0.79166667]
#  [0.08333333 0.58333333]
#  [0.19444444 0.58333333]
#  [0.02777778 0.375     ]
#  [0.16666667 0.45833333]
#  [0.30555556 0.70833333]
#  [0.13888889 0.58333333]
#  [0.13888889 0.41666667]
#  [0.         0.41666667]
#  [0.41666667 0.83333333]
#  [0.38888889 1.        ]
#  [0.30555556 0.79166667]
#  [0.22222222 0.625     ]
#  [0.38888889 0.75      ]
#  [0.22222222 0.75      ]
#  [0.30555556 0.58333333]
#  [0.22222222 0.70833333]
#  [0.08333333 0.66666667]
#  [0.22222222 0.54166667]
#  [0.13888889 0.58333333]
#  [0.19444444 0.41666667]
#  [0.19444444 0.58333333]
#  [0.25       0.625     ]
#  [0.25       0.58333333]
#  [0.11111111 0.5       ]
#  [0.13888889 0.45833333]
#  [0.30555556 0.58333333]
#  [0.25       0.875     ]
#  [0.33333333 0.91666667]
#  [0.16666667 0.45833333]
#  [0.19444444 0.5       ]
#  [0.33333333 0.625     ]
#  [0.16666667 0.45833333]
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
print(scale.fit_transform(df[['1.4','0.2']]))
# Out:
# [[-1.35396443 -1.32506301]
#  [-1.41098555 -1.32506301]
#  [-1.29694332 -1.32506301]
#  [-1.35396443 -1.32506301]
#  [-1.18290109 -1.0614657 ]
#  [-1.35396443 -1.19326436]
#  [-1.29694332 -1.32506301]
#  [-1.35396443 -1.32506301]
#  [-1.29694332 -1.45686167]
#  [-1.29694332 -1.32506301]
#  [-1.23992221 -1.32506301]
#  [-1.35396443 -1.45686167]
#  [-1.52502777 -1.45686167]
#  [-1.46800666 -1.32506301]
#  [-1.29694332 -1.0614657 ]
#  [-1.41098555 -1.0614657 ]
#  [-1.35396443 -1.19326436]
#  [-1.18290109 -1.19326436]
#  [-1.29694332 -1.19326436]
#  [-1.18290109 -1.32506301]
#  [-1.29694332 -1.0614657 ]
#  [-1.58204889 -1.32506301]
#  [-1.18290109 -0.92966704]
#  [-1.06885886 -1.32506301]
#  [-1.23992221 -1.32506301]
#  [-1.23992221 -1.0614657 ]
#  [-1.29694332 -1.32506301]
#  [-1.35396443 -1.32506301]
#  [-1.23992221 -1.32506301]
#  [-1.23992221 -1.32506301]
#  [-1.29694332 -1.0614657 ]
#  [-1.29694332 -1.45686167]
#  [-1.35396443 -1.32506301]
#  [-1.29694332 -1.45686167]
# ...

# %%
df[['1.4']]
# Out:
#      1.4
# 0    1.4
# 1    1.3
# 2    1.5
# 3    1.4
# 4    1.7
# ..   ...
# 144  5.2
# 145  5.0
# 146  5.2
# 147  5.4
# 148  5.1
#
# [149 rows x 1 columns]

# %%
dff=pd.read_csv('homeprices.csv')

# %%
dff
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
dff['town']=le.fit_transform(dff['town'])

# %%
dff
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
from nltk.tokenize import sent_tokenize

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
text='hello vinay.how are you'
print(sent_tokenize(text))
# Out:
# ['hello vinay.how are you']

# %%
from nltk.tokenize import word_tokenize

# %%
print(word_tokenize(text))
# Out:
# ['hello', 'vinay.how', 'are', 'you']

# %%
# nlp is used for text recoginition

# %%
# pip install pipwin

# %%
 #pipwin install pyaudio

# %%
import pyaudio

nltk.download('punkt')
with sr.Microphone() as source:
    print('speak')
try:
    print("text:"+r.recognize_google(audio))
except Exception:
    print('it is not clear....')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pavani\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8320/536171180.py in <module>
#       2
#       3 nltk.download('punkt')
# ----> 4 with sr.Microphone() as source:
#       5     print('speak')
#       6 try:
#
# AttributeError: module 'pyaudio' has no attribute 'Microphone'

# %%
import pyaudio

# %%
import speech_recognition as sr

# %%
r=sr.Recognizer()

# %%
with sr.Microphone() as source:
    print('speak')
    audio=r.listen(source)
try:
    print("text:"+r.recognize_google(audio))
except Exception:
    print("it is not clear")
# Out:
# speak

# %%
df=pd.read_csv(r"C:\Users\pavani\Downloads\RegressionRecuritmentdata1.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   WT      30 non-null     int64
#  1   GD      30 non-null     int64
#  2   Int     30 non-null     int64
#  3   PF      30 non-null     int64
# dtypes: int64(4)
# memory usage: 1.1 KB

# %%
df
# Out:
#     WT  GD  Int  PF
# 0   99   8    9   1
# 1   80   9    7   1
# 2   75   7    7   0
# 3   78   6    8   1
# 4   88   9    5   1
# 5   83   7    8   0
# 6   92   5    8   1
# 7   88   8    9   1
# 8   89   7    9   1
# 9   72   5    8   0
# 10  78   8    6   0
# 11  84   8    7   1
# 12  87   7    8   1
# 13  88   8    8   0
# 14  82   6    9   0
# 15  76   8    9   1
# 16  73   9    9   1
# 17  86   8    7   1
# 18  89   9    7   1
# 19  97   8    8   1
# 20  99   8    9   1
# 21  93   7    6   1
# 22  94   7    7   1
# 23  85   6    6   0
# 24  88   7    6   0
# 25  96   8    9   1
# 26  92   7    6   1
# 27  70   9    8   1
# 28  76   8    5   1
# 29  82   9    8   1

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
X=df.drop(['PF'],axis=1)

# %%
X
# Out:
#     WT  GD  Int
# 0   99   8    9
# 1   80   9    7
# 2   75   7    7
# 3   78   6    8
# 4   88   9    5
# 5   83   7    8
# 6   92   5    8
# 7   88   8    9
# 8   89   7    9
# 9   72   5    8
# 10  78   8    6
# 11  84   8    7
# 12  87   7    8
# 13  88   8    8
# 14  82   6    9
# 15  76   8    9
# 16  73   9    9
# 17  86   8    7
# 18  89   9    7
# 19  97   8    8
# 20  99   8    9
# 21  93   7    6
# 22  94   7    7
# 23  85   6    6
# 24  88   7    6
# 25  96   8    9
# 26  92   7    6
# 27  70   9    8
# 28  76   8    5
# 29  82   9    8

# %%
y=df['PF']

# %%
y
# Out:
# 0     1
# 1     1
# 2     0
# 3     1
# 4     1
# 5     0
# 6     1
# 7     1
# 8     1
# 9     0
# 10    0
# 11    1
# 12    1
# 13    0
# 14    0
# 15    1
# 16    1
# 17    1
# 18    1
# 19    1
# 20    1
# 21    1
# 22    1
# 23    0
# 24    0
# 25    1
# 26    1
# 27    1
# 28    1
# 29    1
# Name: PF, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
sc=MinMaxScaler()

# %%
X_s=pd.DataFrame(sc.fit_transform(X),columns=X.columns)

# %%
X_s
# Out:
#           WT    GD   Int
# 0   1.000000  0.75  1.00
# 1   0.344828  1.00  0.50
# 2   0.172414  0.50  0.50
# 3   0.275862  0.25  0.75
# 4   0.620690  1.00  0.00
# 5   0.448276  0.50  0.75
# 6   0.758621  0.00  0.75
# 7   0.620690  0.75  1.00
# 8   0.655172  0.50  1.00
# 9   0.068966  0.00  0.75
# 10  0.275862  0.75  0.25
# 11  0.482759  0.75  0.50
# 12  0.586207  0.50  0.75
# 13  0.620690  0.75  0.75
# 14  0.413793  0.25  1.00
# 15  0.206897  0.75  1.00
# 16  0.103448  1.00  1.00
# 17  0.551724  0.75  0.50
# 18  0.655172  1.00  0.50
# 19  0.931034  0.75  0.75
# 20  1.000000  0.75  1.00
# 21  0.793103  0.50  0.25
# 22  0.827586  0.50  0.50
# 23  0.517241  0.25  0.25
# 24  0.620690  0.50  0.25
# 25  0.896552  0.75  1.00
# 26  0.758621  0.50  0.25
# 27  0.000000  1.00  0.75
# 28  0.206897  0.75  0.00
# 29  0.413793  1.00  0.75

# %%
X
# Out:
#     WT  GD  Int
# 0   99   8    9
# 1   80   9    7
# 2   75   7    7
# 3   78   6    8
# 4   88   9    5
# 5   83   7    8
# 6   92   5    8
# 7   88   8    9
# 8   89   7    9
# 9   72   5    8
# 10  78   8    6
# 11  84   8    7
# 12  87   7    8
# 13  88   8    8
# 14  82   6    9
# 15  76   8    9
# 16  73   9    9
# 17  86   8    7
# 18  89   9    7
# 19  97   8    8
# 20  99   8    9
# 21  93   7    6
# 22  94   7    7
# 23  85   6    6
# 24  88   7    6
# 25  96   8    9
# 26  92   7    6
# 27  70   9    8
# 28  76   8    5
# 29  82   9    8

# %%
X_s.shape
# Out:
# (30, 3)

# %%
X_train,X_test,y_train,y_test=train_test_split(X_s,y,test_size=0.2)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Dropout,BatchNormalization

# %%
model=Sequential()
model.add(Dense(128,activation='relu',input_dim=3)) #input layer
model.add(Dropout(0.5))
model.add(Dense(28,activation='relu')) # hidden layer
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid')) # output layer
model.add(Dropout(0.5))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
hist=model.fit(X_train,y_train,batch_size=32,epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 1s 691ms/step - loss: 5.9564 - accuracy: 0.5833
# Epoch 2/10
# 1/1 [==============================] - 0s 16ms/step - loss: 7.8323 - accuracy: 0.4583
# Epoch 3/10
# 1/1 [==============================] - 0s 16ms/step - loss: 7.5721 - accuracy: 0.4167
# Epoch 4/10
# 1/1 [==============================] - 0s 16ms/step - loss: 5.7581 - accuracy: 0.6250
# Epoch 5/10
# 1/1 [==============================] - 0s 5ms/step - loss: 9.0653 - accuracy: 0.3750
# Epoch 6/10
# 1/1 [==============================] - 0s 9ms/step - loss: 8.0315 - accuracy: 0.4167
# Epoch 7/10
# 1/1 [==============================] - 0s 8ms/step - loss: 6.5224 - accuracy: 0.5417
# Epoch 8/10
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8794 - accuracy: 0.5000
# Epoch 9/10
# 1/1 [==============================] - 0s 8ms/step - loss: 10.4124 - accuracy: 0.2917
# Epoch 10/10
# ...

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

#Initializing Neural Network
classifier = Sequential()
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 3))
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(activation="sigmoid", units=1))
# Compiling Neural Network
classifier.compile(optimizer = 'Adagrad', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Fitting our model 
classifier.fit(X_train, y_train, batch_size = 32, epochs = 15)
# Out:
# Epoch 1/15
# 1/1 [==============================] - 1s 552ms/step - loss: 0.6929 - accuracy: 0.7083
# Epoch 2/15
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6928 - accuracy: 0.7083
# Epoch 3/15
# 1/1 [==============================] - 0s 0s/step - loss: 0.6927 - accuracy: 0.7083
# Epoch 4/15
# 1/1 [==============================] - 0s 0s/step - loss: 0.6926 - accuracy: 0.7083
# Epoch 5/15
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6924 - accuracy: 0.7083
# Epoch 6/15
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6923 - accuracy: 0.7083
# Epoch 7/15
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6922 - accuracy: 0.7083
# Epoch 8/15
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6921 - accuracy: 0.7083
# Epoch 9/15
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6920 - accuracy: 0.7083
# Epoch 10/15
# ...

# %%
from sklearn import  datasets

# %%
datasets
# Out:
# <module 'sklearn.datasets' from 'C:\\Users\\pavani\\anaconda3\\lib\\site-packages\\sklearn\\datasets\\__init__.py'>
